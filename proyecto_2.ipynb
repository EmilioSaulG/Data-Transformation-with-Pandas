# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilioSaulG/Data-Transformation-with-Pandas/blob/proyecto-2/proyecto_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ventas online**

# %%
import pandas as pd

# %%
datos = pd.read_json('/content/dados_locacao_imoveis_proyecto_2.json')

# %%
datos
# Out:
#                                         dados_locacao
# 0   {'apartamento': 'A101 (blocoAP)', 'datas_combi...
# 1   {'apartamento': 'A102 (blocoAP)', 'datas_combi...
# 2   {'apartamento': 'B201 (blocoAP)', 'datas_combi...
# 3   {'apartamento': 'B202 (blocoAP)', 'datas_combi...
# 4   {'apartamento': 'C301 (blocoAP)', 'datas_combi...
# 5   {'apartamento': 'C302 (blocoAP)', 'datas_combi...
# 6   {'apartamento': 'D401 (blocoAP)', 'datas_combi...
# 7   {'apartamento': 'D402 (blocoAP)', 'datas_combi...
# 8   {'apartamento': 'E501 (blocoAP)', 'datas_combi...
# 9   {'apartamento': 'E502 (blocoAP)', 'datas_combi...
# 10  {'apartamento': 'F601 (blocoAP)', 'datas_combi...
# 11  {'apartamento': 'F602 (blocoAP)', 'datas_combi...
# 12  {'apartamento': 'G701 (blocoAP)', 'datas_combi...
# 13  {'apartamento': 'G702 (blocoAP)', 'datas_combi...
# 14  {'apartamento': 'H801 (blocoAP)', 'datas_combi...

# %%
datos = pd.json_normalize(datos['dados_locacao'])
datos.head(10)
# Out:
#       apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0  A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1  A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2  B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3  B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4  C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
# 5  C302 (blocoAP)   [06/06/2022, 06/07/2022]  [08/06/2022, 12/07/2022]
# 6  D401 (blocoAP)   [07/06/2022, 07/07/2022]  [07/06/2022, 09/07/2022]
# 7  D402 (blocoAP)   [08/06/2022, 08/07/2022]  [10/06/2022, 14/07/2022]
# 8  E501 (blocoAP)   [09/06/2022, 09/07/2022]  [10/06/2022, 09/07/2022]
# 9  E502 (blocoAP)   [10/06/2022, 10/07/2022]  [16/06/2022, 12/07/2022]
#
#                       valor_aluguel
# 0  [$ 1000,0 reais, $ 2500,0 reais]
# 1  [$ 1100,0 reais, $ 2600,0 reais]
# 2  [$ 1200,0 reais, $ 2700,0 reais]
# 3  [$ 1300,0 reais, $ 2800,0 reais]
# ...

# %%
columnas = list(datos.columns)
columnas
# Out:
# ['apartamento',
#  'datas_combinadas_pagamento',
#  'datas_de_pagamento',
#  'valor_aluguel']

# %%
datos = datos.explode(columnas[1:])

# %%
datos.reset_index(drop=True, inplace=True)

# %%
datos
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022
# 11  C302 (blocoAP)                 06/07/2022         12/07/2022
# 12  D401 (blocoAP)                 07/06/2022         07/06/2022
# ...

# %%
import numpy as np

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
datos['valor_aluguel'] = datos['valor_aluguel'].apply(lambda x: x.replace('$','').replace(' reais', '').replace(',','.').strip())

# %%
datos['valor_aluguel'] = datos['valor_aluguel'].astype(np.float64)

# %%
datos['valor_aluguel']
# Out:
# 0     1000.0
# 1     2500.0
# 2     1100.0
# 3     2600.0
# 4     1200.0
# 5     2700.0
# 6     1300.0
# 7     2800.0
# 8     1400.0
# 9     2900.0
# 10    1500.0
# 11    1200.0
# 12    1600.0
# 13    1300.0
# 14    1700.0
# 15    1400.0
# 16    1800.0
# 17    1500.0
# 18    1900.0
# 19    1600.0
# 20    2000.0
# 21    1000.0
# 22    2100.0
# 23    1100.0
# 24    2200.0
# 25    1200.0
# 26    2300.0
# 27    2100.0
# 28    2400.0
# 29    2200.0
# Name: valor_aluguel, dtype: float64

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB

# %%
datos['apartamento'].str.replace(' \(blocoAP\)', '')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-518784343.py:1: SyntaxWarning: invalid escape sequence '\('
#   datos['apartamento'].str.replace(' \(blocoAP\)', '')
# 0     A101 (blocoAP)
# 1     A101 (blocoAP)
# 2     A102 (blocoAP)
# 3     A102 (blocoAP)
# 4     B201 (blocoAP)
# 5     B201 (blocoAP)
# 6     B202 (blocoAP)
# 7     B202 (blocoAP)
# 8     C301 (blocoAP)
# 9     C301 (blocoAP)
# 10    C302 (blocoAP)
# 11    C302 (blocoAP)
# 12    D401 (blocoAP)
# 13    D401 (blocoAP)
# 14    D402 (blocoAP)
# 15    D402 (blocoAP)
# 16    E501 (blocoAP)
# 17    E501 (blocoAP)
# 18    E502 (blocoAP)
# 19    E502 (blocoAP)
# 20    F601 (blocoAP)
# 21    F601 (blocoAP)
# 22    F602 (blocoAP)
# 23    F602 (blocoAP)
# 24    G701 (blocoAP)
# 25    G701 (blocoAP)
# 26    G702 (blocoAP)
# 27    G702 (blocoAP)
# 28    H801 (blocoAP)
# 29    H801 (blocoAP)
# Name: apartamento, dtype: object

# %%
datos['apartamento'] = datos['apartamento'].str.replace(' \(blocoAP\)', '')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-514622174.py:1: SyntaxWarning: invalid escape sequence '\('
#   datos['apartamento'] = datos['apartamento'].str.replace(' \(blocoAP\)', '')

# %%
datos
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022
# 11  C302 (blocoAP)                 06/07/2022         12/07/2022
# 12  D401 (blocoAP)                 07/06/2022         07/06/2022
# ...

# %%
datos['datas_combinadas_pagamento'] = pd.to_datetime(datos['datas_combinadas_pagamento'], format='%d/%m/%Y')
datos['datas_de_pagamento'] = pd.to_datetime(datos['datas_de_pagamento'], format='%d/%m/%Y')

# %%
datos
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 2022-06-01         2022-06-05
# 1   A101 (blocoAP)                 2022-07-01         2022-07-03
# 2   A102 (blocoAP)                 2022-06-02         2022-06-02
# 3   A102 (blocoAP)                 2022-07-02         2022-07-06
# 4   B201 (blocoAP)                 2022-06-03         2022-06-07
# 5   B201 (blocoAP)                 2022-07-03         2022-07-03
# 6   B202 (blocoAP)                 2022-06-04         2022-06-07
# 7   B202 (blocoAP)                 2022-07-04         2022-07-05
# 8   C301 (blocoAP)                 2022-06-05         2022-06-10
# 9   C301 (blocoAP)                 2022-07-05         2022-07-09
# 10  C302 (blocoAP)                 2022-06-06         2022-06-08
# 11  C302 (blocoAP)                 2022-07-06         2022-07-12
# 12  D401 (blocoAP)                 2022-06-07         2022-06-07
# ...

# %%
datos['atraso'] = (datos['datas_de_pagamento'] - datos['datas_combinadas_pagamento']).dt.days

# %%
datos
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 2022-06-01         2022-06-05
# 1   A101 (blocoAP)                 2022-07-01         2022-07-03
# 2   A102 (blocoAP)                 2022-06-02         2022-06-02
# 3   A102 (blocoAP)                 2022-07-02         2022-07-06
# 4   B201 (blocoAP)                 2022-06-03         2022-06-07
# 5   B201 (blocoAP)                 2022-07-03         2022-07-03
# 6   B202 (blocoAP)                 2022-06-04         2022-06-07
# 7   B202 (blocoAP)                 2022-07-04         2022-07-05
# 8   C301 (blocoAP)                 2022-06-05         2022-06-10
# 9   C301 (blocoAP)                 2022-07-05         2022-07-09
# 10  C302 (blocoAP)                 2022-06-06         2022-06-08
# 11  C302 (blocoAP)                 2022-07-06         2022-07-12
# 12  D401 (blocoAP)                 2022-06-07         2022-06-07
# ...

# %%
media_atraso = datos.groupby(['apartamento'])['atraso'].mean()

# %%
media_atraso
# Out:
# apartamento
# A101 (blocoAP)    3.0
# A102 (blocoAP)    2.0
# B201 (blocoAP)    2.0
# B202 (blocoAP)    2.0
# C301 (blocoAP)    4.5
# C302 (blocoAP)    4.0
# D401 (blocoAP)    1.0
# D402 (blocoAP)    4.0
# E501 (blocoAP)    0.5
# E502 (blocoAP)    4.0
# F601 (blocoAP)    4.0
# F602 (blocoAP)    1.5
# G701 (blocoAP)    6.5
# G702 (blocoAP)    2.0
# H801 (blocoAP)    2.0
# Name: atraso, dtype: float64
